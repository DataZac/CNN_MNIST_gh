# %% [markdown]
# # Tenforflow - CNN
#  The idea of this project is to implement a CNN architecture which was made up beforehand. Also, the network is trained on a small subset of the MNIST data. The small size was chosen due to performance reasons on a local machine.
#
#
# The handwritten notes illustrate a process of data transformations. The transformations are necessary to be performed when building a CCN. They are also necessary for evaluating the model. The notes should clearly show how the transformations are performed. The notes contain all crucial transformations and thus allow to help to design an arbitraty CNN in tensorflow.

# %% [markdown]
# ![alt text](cnn.png "Title")

# %%
# https://adeshpande3.github.io/A-Beginner%27s-Guide-To-Understanding-Convolutional-Neural-Networks-Part-2/
# https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/02_Convolutional_Neural_Network.ipynb
# exec(open('test_tensorshapes.py').read())
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
tf.__version__
# Out:
# '1.5.0'

# %%
# Parameters
learning_rate = 0.001
training_iters = 180000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# load data
#with tf.device('/cpu:0'):
    #mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# network variables and parameters
# Store layers weight & bias
weights = {
    # 5x5 conv/filter size,  input, outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 16])),
    # 5x5 conv/filter size, inputs, outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 16, 64])),
    # fully connected, 7*7*16 inputs, 1024 outputs
    'wf1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'wf2': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([16])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bf1': tf.Variable(tf.random_normal([1024])),
    'bf2': tf.Variable(tf.random_normal([n_classes]))
}
# Out:
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Encapsuling the net building blocks
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b, name = 'Conv2d')
    print(x)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    x = tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME', name = 'Maxpool')
    print(x)
    return x

def fully(x, weights, biases):
    # Fully connected layer wrapper
    x = tf.matmul(x, weights, name = 'Fully')
    x = tf.add(x, biases, name = 'Fully_bias')
    print(x)
    return tf.nn.relu(x)
    
    
# Make model
def conv_net(x, weights, biases, dropout):
    # Tensorize input pictures
    x = tf.reshape(x, shape=[-1, 28, 28, 1], name = 'Rawinputtotensor')
    print(x)
    
    # Convolution and poolling layers
    tensor = conv2d(x, weights['wc1'], biases['bc1'])
    tensor = maxpool2d(tensor, k=2)
    tensor = conv2d(tensor, weights['wc2'], biases['bc2'])
    tensor = maxpool2d(tensor, k=2)

    # Fully connected layers
    tensor = tf.reshape(tensor, [-1, weights['wf1'].get_shape().as_list()[0]], name = 'reshape')
    print(tensor)
    tensor = fully(tensor, weights['wf1'], biases['bf1'])

    # Apply Dropout
    tensor = tf.nn.dropout(tensor, dropout, name = 'Drop_out')

    # Output layer, a.k.a. fully connected layer 2, class prediction
    tensor = tf.add(tf.matmul(tensor, weights['wf2']), biases['bf2'], name = 'Output_Conv_net')
    print(tensor)
    
    
    return tensor

y_pred = conv_net(x, weights, biases, dropout)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(y_pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()
# Out:
# Tensor("Rawinputtotensor_1:0", shape=(?, 28, 28, 1), dtype=float32)
# Tensor("Conv2d_2:0", shape=(?, 28, 28, 16), dtype=float32)
# Tensor("Maxpool_2:0", shape=(?, 14, 14, 16), dtype=float32)
# Tensor("Conv2d_3:0", shape=(?, 14, 14, 64), dtype=float32)
# Tensor("Maxpool_3:0", shape=(?, 7, 7, 64), dtype=float32)
# Tensor("reshape_1:0", shape=(?, 3136), dtype=float32)
# Tensor("Fully_bias:0", shape=(?, 1024), dtype=float32)
# Tensor("Output_Conv_net:0", shape=(?, 10), dtype=float32)
# WARNING:tensorflow:From <ipython-input-6-9b36a63b5245>:55: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ### Run for interactive learning progress visualization:

# %%
# %matplotlib notebook
import numpy as np
import time
import matplotlib

from matplotlib import pyplot as plt
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    steps = []
    losses = []
    accs = []
    # Keep training until reach max iterations

    fig, ax = plt.subplots(1, 1)
    ax2 = ax.twinx()

    #plt.show(False)
    #plt.draw()
    #points = ax.plot(1, 13000, 'o')[0]
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " +  "{:.5f}".format(acc))
            
            steps.append(step)
            losses.append(loss)
            accs.append(acc)

            #ax.set_aspect('equal')
            #ax.set_xlim(0, 10000)
            #ax.set_ylim(0, 10000)
            #ax.hold(True)
            #ax.autoscale(axis = 'both')
            #points.set_data(step, loss)
            ax.plot(steps, losses, color='b')            
            ax.set_xlabel('step')
            ax.set_ylabel('loss')
            ax.autoscale(axis = 'both')
            
            ax2.plot(steps, accs, color='r')
            ax2.set_ylabel('accuracy')
            ax2.autoscale(axis = 'both')
            plt.tight_layout(rect = (.1, .1, .85, .85))
            
            fig.canvas.draw()
           
            
        step += 1
    plt.close(fig)
    print ("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print ("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# Iter 1280, Minibatch Loss= 44871.281250, Training Accuracy= 0.14062
# Iter 2560, Minibatch Loss= 27129.466797, Training Accuracy= 0.36719
# Iter 3840, Minibatch Loss= 16872.988281, Training Accuracy= 0.42188
# Iter 5120, Minibatch Loss= 12489.018555, Training Accuracy= 0.53125
# Iter 6400, Minibatch Loss= 11200.578125, Training Accuracy= 0.57812
# Iter 7680, Minibatch Loss= 8183.806641, Training Accuracy= 0.65625
# Iter 8960, Minibatch Loss= 7919.433105, Training Accuracy= 0.68750
# Iter 10240, Minibatch Loss= 4888.582031, Training Accuracy= 0.75000
# Iter 11520, Minibatch Loss= 4961.608398, Training Accuracy= 0.70312
# Iter 12800, Minibatch Loss= 2855.246582, Training Accuracy= 0.82031
# Iter 14080, Minibatch Loss= 3960.294434, Training Accuracy= 0.82812
# Iter 15360, Minibatch Loss= 4535.258789, Training Accuracy= 0.78906
# Iter 16640, Minibatch Loss= 3630.358887, Training Accuracy= 0.81250
# Iter 17920, Minibatch Loss= 5044.234863, Training Accuracy= 0.77344
# Iter 19200, Minibatch Loss= 4381.176270, Training Accuracy= 0.77344
# Iter 20480, Minibatch Loss= 3796.516113, Training Accuracy= 0.82812
# Iter 21760, Minibatch Loss= 2671.749268, Training Accuracy= 0.84375
# Iter 23040, Minibatch Loss= 3440.913574, Training Accuracy= 0.80469
# Iter 24320, Minibatch Loss= 2386.463623, Training Accuracy= 0.87500
# Iter 25600, Minibatch Loss= 4174.610352, Training Accuracy= 0.80469
# Iter 26880, Minibatch Loss= 2574.475098, Training Accuracy= 0.82031
# Iter 28160, Minibatch Loss= 3759.647949, Training Accuracy= 0.81250
# Iter 29440, Minibatch Loss= 2884.858887, Training Accuracy= 0.85156
# Iter 30720, Minibatch Loss= 2071.351074, Training Accuracy= 0.85938
# Iter 32000, Minibatch Loss= 1910.274658, Training Accuracy= 0.87500
# Iter 33280, Minibatch Loss= 2485.270752, Training Accuracy= 0.83594
# Iter 34560, Minibatch Loss= 2098.966797, Training Accuracy= 0.85938
# Iter 35840, Minibatch Loss= 2960.754883, Training Accuracy= 0.85156
# Iter 37120, Minibatch Loss= 1517.551758, Training Accuracy= 0.87500
# Iter 38400, Minibatch Loss= 2457.921387, Training Accuracy= 0.89062
# Iter 39680, Minibatch Loss= 1570.087402, Training Accuracy= 0.86719
# Iter 40960, Minibatch Loss= 1241.343018, Training Accuracy= 0.87500
# Iter 42240, Minibatch Loss= 2061.066406, Training Accuracy= 0.89844
# Iter 43520, Minibatch Loss= 2332.024170, Training Accuracy= 0.85938
# Iter 44800, Minibatch Loss= 1473.684814, Training Accuracy= 0.89062
# Iter 46080, Minibatch Loss= 1119.964844, Training Accuracy= 0.89062
# Iter 47360, Minibatch Loss= 2290.167480, Training Accuracy= 0.85156
# Iter 48640, Minibatch Loss= 970.474365, Training Accuracy= 0.92188
# Iter 49920, Minibatch Loss= 1279.831909, Training Accuracy= 0.86719
# Iter 51200, Minibatch Loss= 343.477997, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 662.600708, Training Accuracy= 0.91406
# Iter 53760, Minibatch Loss= 1362.211548, Training Accuracy= 0.89062
# Iter 55040, Minibatch Loss= 1125.706055, Training Accuracy= 0.92188
# Iter 56320, Minibatch Loss= 1054.651611, Training Accuracy= 0.87500
# Iter 57600, Minibatch Loss= 1526.405273, Training Accuracy= 0.83594
# Iter 58880, Minibatch Loss= 1490.280518, Training Accuracy= 0.90625
# Iter 60160, Minibatch Loss= 935.590393, Training Accuracy= 0.90625
# Iter 61440, Minibatch Loss= 814.406982, Training Accuracy= 0.92969
# Iter 62720, Minibatch Loss= 933.171204, Training Accuracy= 0.89844
# Iter 64000, Minibatch Loss= 708.416443, Training Accuracy= 0.89062
# Iter 65280, Minibatch Loss= 492.060242, Training Accuracy= 0.96094
# Iter 66560, Minibatch Loss= 891.500244, Training Accuracy= 0.89062
# Iter 67840, Minibatch Loss= 698.655823, Training Accuracy= 0.91406
# Iter 69120, Minibatch Loss= 1145.365234, Training Accuracy= 0.89844
# Iter 70400, Minibatch Loss= 511.900909, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 692.775391, Training Accuracy= 0.92188
# Iter 72960, Minibatch Loss= 632.014282, Training Accuracy= 0.92188
# Iter 74240, Minibatch Loss= 382.258789, Training Accuracy= 0.93750
# Iter 75520, Minibatch Loss= 470.076599, Training Accuracy= 0.91406
# Iter 76800, Minibatch Loss= 579.859985, Training Accuracy= 0.94531
# Iter 78080, Minibatch Loss= 664.433899, Training Accuracy= 0.90625
# Iter 79360, Minibatch Loss= 587.576721, Training Accuracy= 0.92188
# Iter 80640, Minibatch Loss= 1029.743164, Training Accuracy= 0.92969
# Iter 81920, Minibatch Loss= 1610.001465, Training Accuracy= 0.91406
# Iter 83200, Minibatch Loss= 434.110352, Training Accuracy= 0.92969
# Iter 84480, Minibatch Loss= 808.210571, Training Accuracy= 0.90625
# Iter 85760, Minibatch Loss= 814.203674, Training Accuracy= 0.91406
# Iter 87040, Minibatch Loss= 1366.178711, Training Accuracy= 0.89844
# Iter 88320, Minibatch Loss= 968.483276, Training Accuracy= 0.91406
# Iter 89600, Minibatch Loss= 332.323059, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 968.674805, Training Accuracy= 0.92188
# Iter 92160, Minibatch Loss= 821.697632, Training Accuracy= 0.94531
# Iter 93440, Minibatch Loss= 722.030029, Training Accuracy= 0.92188
# Iter 94720, Minibatch Loss= 412.046326, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 551.348206, Training Accuracy= 0.92969
# Iter 97280, Minibatch Loss= 298.788879, Training Accuracy= 0.93750
# Iter 98560, Minibatch Loss= 1008.868652, Training Accuracy= 0.89844
# Iter 99840, Minibatch Loss= 583.129517, Training Accuracy= 0.93750
# Iter 101120, Minibatch Loss= 806.263672, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 367.992737, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 476.622437, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 907.754761, Training Accuracy= 0.90625
# Iter 106240, Minibatch Loss= 481.202850, Training Accuracy= 0.92969
# Iter 107520, Minibatch Loss= 634.723694, Training Accuracy= 0.93750
# Iter 108800, Minibatch Loss= 376.967896, Training Accuracy= 0.94531
# Iter 110080, Minibatch Loss= 868.635376, Training Accuracy= 0.92969
# Iter 111360, Minibatch Loss= 961.751282, Training Accuracy= 0.92969
# Iter 112640, Minibatch Loss= 608.326904, Training Accuracy= 0.92969
# Iter 113920, Minibatch Loss= 152.684021, Training Accuracy= 0.95312
# Iter 115200, Minibatch Loss= 274.469330, Training Accuracy= 0.95312
# Iter 116480, Minibatch Loss= 254.515350, Training Accuracy= 0.95312
# Iter 117760, Minibatch Loss= 208.489349, Training Accuracy= 0.94531
# Iter 119040, Minibatch Loss= 387.709625, Training Accuracy= 0.92188
# Iter 120320, Minibatch Loss= 302.813141, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 263.175171, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 1038.922852, Training Accuracy= 0.87500
# Iter 124160, Minibatch Loss= 363.635712, Training Accuracy= 0.94531
# Iter 125440, Minibatch Loss= 741.173218, Training Accuracy= 0.92188
# Iter 126720, Minibatch Loss= 723.106445, Training Accuracy= 0.89844
# Iter 128000, Minibatch Loss= 444.713623, Training Accuracy= 0.94531
# Iter 129280, Minibatch Loss= 317.651245, Training Accuracy= 0.93750
# Iter 130560, Minibatch Loss= 347.433502, Training Accuracy= 0.92188
# Iter 131840, Minibatch Loss= 304.884644, Training Accuracy= 0.95312
# Iter 133120, Minibatch Loss= 383.911377, Training Accuracy= 0.92188
# Iter 134400, Minibatch Loss= 306.978851, Training Accuracy= 0.92969
# Iter 135680, Minibatch Loss= 195.213043, Training Accuracy= 0.95312
# Iter 136960, Minibatch Loss= 176.927704, Training Accuracy= 0.95312
# Iter 138240, Minibatch Loss= 401.255035, Training Accuracy= 0.93750
# Iter 139520, Minibatch Loss= 175.150406, Training Accuracy= 0.96875
# Iter 140800, Minibatch Loss= 163.664948, Training Accuracy= 0.92969
# Iter 142080, Minibatch Loss= 457.326324, Training Accuracy= 0.92969
# Iter 143360, Minibatch Loss= 165.780365, Training Accuracy= 0.96094
# Iter 144640, Minibatch Loss= 264.553650, Training Accuracy= 0.92969
# Iter 145920, Minibatch Loss= 441.588379, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 311.821289, Training Accuracy= 0.96094
# Iter 148480, Minibatch Loss= 196.066864, Training Accuracy= 0.93750
# Iter 149760, Minibatch Loss= 439.429260, Training Accuracy= 0.95312
# Iter 151040, Minibatch Loss= 191.423294, Training Accuracy= 0.96094
# Iter 152320, Minibatch Loss= 313.144745, Training Accuracy= 0.94531
# Iter 153600, Minibatch Loss= 352.364624, Training Accuracy= 0.92969
# Iter 154880, Minibatch Loss= 287.299316, Training Accuracy= 0.95312
# Iter 156160, Minibatch Loss= 95.034203, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 664.663879, Training Accuracy= 0.90625
# Iter 158720, Minibatch Loss= 655.911621, Training Accuracy= 0.89062
# Iter 160000, Minibatch Loss= 179.546036, Training Accuracy= 0.95312
# Iter 161280, Minibatch Loss= 221.799988, Training Accuracy= 0.94531
# Iter 162560, Minibatch Loss= 469.901520, Training Accuracy= 0.94531
# Iter 163840, Minibatch Loss= 163.979767, Training Accuracy= 0.95312
# Iter 165120, Minibatch Loss= 137.578064, Training Accuracy= 0.93750
# Iter 166400, Minibatch Loss= 393.827637, Training Accuracy= 0.92188
# Iter 167680, Minibatch Loss= 266.088318, Training Accuracy= 0.93750
# Iter 168960, Minibatch Loss= 179.959061, Training Accuracy= 0.94531
# Iter 170240, Minibatch Loss= 244.603333, Training Accuracy= 0.94531
# Iter 171520, Minibatch Loss= 176.053192, Training Accuracy= 0.96094
# Iter 172800, Minibatch Loss= 451.668671, Training Accuracy= 0.89844
# Iter 174080, Minibatch Loss= 365.470154, Training Accuracy= 0.96094
# Iter 175360, Minibatch Loss= 286.092468, Training Accuracy= 0.94531
# Iter 176640, Minibatch Loss= 236.566132, Training Accuracy= 0.96094
# Iter 177920, Minibatch Loss= 105.110207, Training Accuracy= 0.94531
# Iter 179200, Minibatch Loss= 392.057434, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.9765625
